# %% [markdown]
# ##### 2. (그림4-15)는 3차원 구조를 가진 데이터이다. [그림4-15(a)]와 [그림4-15(b)]를 위한 컨볼루션 수식을 식(4.11)을 참조하여 각각 제시하시오.
# ![Alt text](image.png)
#
# $$s(i, j, k)=\sum_{x=-\left(h_x-1\right) / 2}^{\left(h_x-1\right) / 2} \sum_{y=-\left(h_y-1\right) / 2}^{\left(h_y-1\right) / 2} \sum_{z=-\left(h_z-1\right) / 2}^{\left(h_z-1\right) / 2} z(i+x, j+y, k+z) \cdot u(x, y, z)$$

# %% [markdown]
# ##### 5. 다음은 은닉층이 3개인 DMLP이다.
#
# $$
# \text { 가중치 행렬: } \mathbf{U}^l=\left(\begin{array}{cccc}
# u_{10}^l & u_{11}^l & \cdots & u_{1 l_{l-1}}^l \\
# u_{20}^l & u_{21}^l & \cdots & u_{2 n_{l-1}}^l \\
# \vdots & \vdots & \ddots & \vdots \\
# u_{n_l 0}^l & u_{n_1 1}^l & \cdots & u_{n_l n_{l-1}}^l
# \end{array}\right), l=1,2, \cdots, L
# $$
#
# 1. 가중치 행렬 $U^1, U^2, U^3, U^4$를 식 (4.1)처럼 쓰시오
# 2. x=(1, 0)^T가 입력되었을 때 출력 o를 구하시오. 활성함수로 로지스틱 시그모이드를 사용하시오.

# %%
import numpy as np

x_0 = np.array([
    [0.3, 1.6],
    [1.0, 0.7],
    [0.5, -0.1],
    [1.0, -0.2]
])

x_1 = np.array([
    [1.0, -1.1],
    [1.0, 0.5],
    [-0.8, 0.3],
    [0.1, 1.3]
])

x_2 = np.array([
    [1.2, -1.1],
    [-1.0, 1.0],
    [1.0, 0.4],
    [-0.2, -0.4]
])

# %%
U_1 = np.array([x_0[0], x_1[0], x_2[0]]).T
U_2 = np.array([x_0[1], x_1[1], x_2[1]]).T
U_3 = np.array([x_0[2], x_1[2], x_2[2]]).T
U_4 = np.array([x_0[3], x_1[3], x_2[3]]).T

print(f"{U_1=}\n")
print(f"{U_2=}\n")
print(f"{U_3=}\n")
print(f"{U_4=}")
# Out:
# U_1=array([[ 0.3,  1. ,  1.2],
#        [ 1.6, -1.1, -1.1]])
#
# U_2=array([[ 1. ,  1. , -1. ],
#        [ 0.7,  0.5,  1. ]])
#
# U_3=array([[ 0.5, -0.8,  1. ],
#        [-0.1,  0.3,  0.4]])
#
# U_4=array([[ 1. ,  0.1, -0.2],
#        [-0.2,  1.3, -0.4]])

# %%
np.array([1])+x_t
# Out:
# array([2, 1])

# %%
o_1.to_list
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 o_1.to_list
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_list'

# %%
np.array([1] + list(o_1))
# Out:
# array([1.        , 0.90024951, 0.7109495 , 0.78583498])

# %%
# Out:
# [0.72004652 0.60673135]

# %% [markdown]
# ##### 7. 나머지 8개 화소의 값을 계산하시오.

# %%
r = np.array([
    [1,1,1],
    [2,1,3],
    [0,1,0]
])

g = np.array([
    [2,2,2],
    [1,0,1],
    [0,3,0]
])

b = np.array([
    [0,3,0],
    [1,0,1],
    [1,0,0]
])

kernel = np.array([])

# %% [markdown]
# ##### 11. [그림 4-14]를 [그림 4-15] 형식으로 다시 그리시오.
# ![image.png](attachment:image.png)
